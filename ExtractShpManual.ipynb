# %% [markdown]
# <a href="https://colab.research.google.com/github/widifadi/AutomateConversion/blob/main/ExtractShpManual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.flush_and_unmount()
# Out:
# Drive not mounted, so nothing to flush and unmount.

# %%
from google.colab import drive

# Check if drive is already mounted
import os
if not os.path.exists('/content/drive'):
  drive.mount('/content/drive')
else:
  print("Google Drive is already mounted at /content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib pandas geopandas shapely > /dev/null 2>&1

from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()
gc = gspread.authorize(creds)

from googleapiclient.discovery import build
from googleapiclient.http import MediaIoBaseDownload
import io

import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, LineString, MultiPoint
import os
import numpy as np # import numpy to help filter out invalid coordinate values
import warnings # import the warnings module
import shutil

# Replace with your file ID
file_id = '1m23mu_aiwSIxo22uZuR-ROVt3hgwdeDRObge6ZFoNRA'  # extract file ID from the Google Sheet URL

# Replace with your desired output folder
output_folder = '/content/drive/MyDrive/LALIN DC/Final Upload Shp v2'
os.makedirs(output_folder, exist_ok=True)

# Build the Drive API client
drive_service = build('drive', 'v3', credentials=creds)

# Export the spreadsheet file to Excel format
request = drive_service.files().export_media(fileId=file_id, mimeType='application/vnd.openxmlformats-officedocument.spreadsheetml.sheet')
# using export_media to export the file to a downloadable format, which is Excel (xlsx) in this case
fh = io.BytesIO()
downloader = MediaIoBaseDownload(fh, request)
done = False
while done is False:
    status, done = downloader.next_chunk()
    print("Download %d%%." % int(status.progress() * 100))

# Load the spreadsheet into pandas
df_dict = pd.read_excel(fh, sheet_name=None) # read the downloaded excel file using pandas
fh.close()  # to prevent problems during execution

# Dictionary to store problematic records per sheet
problematic_records_dict = {}

# Process the data as before, starting from the loop that iterates over sheets
for sheet_name, df in list(df_dict.items())[2:]: # iterating through the sheets using the data from 'df', not 'sheets_dict'
    print(f"Processing sheet: {sheet_name}")

    problematic_records = []

    # Handle different geometry types based on sheet names
    if sheet_name == "4 PAGAR PENGAMAN" or sheet_name == "5 MARKA":
        geometry_with_indices = []

        for index, row in df.iterrows():
            try:
                lon1, lat1 = row['TitikKoordinatAwal_Longitude'], row['TitikKoordinatAwal_Latitude']
                lon2, lat2 = row['TitikKoordinatAkhir_Longitude'], row['TitikKoordinatAkhir_Latitude']

                # Convert valid numeric values; set invalid values to NaN manually
                def safe_float(value):
                    return float(value) if value not in ["", "-", None] else np.nan

                lon1, lat1, lon2, lat2 = map(safe_float, [lon1, lat1, lon2, lat2])

                # Check validity
                start_valid = np.isfinite(lon1) and np.isfinite(lat1)
                end_valid = np.isfinite(lon2) and np.isfinite(lat2)

                if sheet_name == "4 PAGAR PENGAMAN":
                    if start_valid and end_valid:
                        geometry_with_indices.append((index, LineString([(lon1, lat1), (lon2, lat2)])))
                    elif start_valid:
                        geometry_with_indices.append((index, LineString([(lon1, lat1), (lon1, lat1)])))  # Degenerate LineString
                        problematic_records.append(row.to_dict())
                    elif end_valid:
                        geometry_with_indices.append((index, LineString([(lon2, lat2), (lon2, lat2)])))  # Degenerate LineString
                        problematic_records.append(row.to_dict())
                    else:
                        print(f"Skipping row {index} due to completely missing coordinates in sheet {sheet_name}")
                        problematic_records.append(row.to_dict())

                elif sheet_name == "5 MARKA":
                    points = []
                    if start_valid:
                        points.append(Point(lon1, lat1))
                    if end_valid:
                        points.append(Point(lon2, lat2))

                    # If either one or both coordinates are invalid, add to problematic records
                    if len(points) < 2:  # This ensures records with 0 or 1 valid points are stored
                        problematic_records.append(row.to_dict())

                    if points:  # If at least one valid point exists
                        geometry_with_indices.append((index, MultiPoint(points)))
                    else:
                        print(f"Skipping row {index} due to completely invalid coordinates in sheet {sheet_name}")
                        problematic_records.append(row.to_dict())

            except (KeyError, TypeError):
                print(f"Skipping row {index} due to missing or invalid coordinates in sheet {sheet_name}")
                problematic_records.append(row.to_dict())
                continue

        # Extract geometries and valid indices
        geometry = [geom for _, geom in geometry_with_indices]
        valid_indices = [index for index, _ in geometry_with_indices]

        # Filter the DataFrame to keep only rows with valid geometries
        df = df.loc[valid_indices].reset_index(drop=True)

    else:
        # Create a list to store valid geometries and their corresponding indices
        geometry_with_indices = []
        for index, row in df.iterrows():
            try:
                # Filter out invalid coordinates (NaN, inf, -inf)
                lon = float(row['Longitude'])
                lat = float(row['Latitude'])

                if np.isfinite(lon) and np.isfinite(lat):
                    geometry_with_indices.append((index, Point(lon, lat)))
                else:
                    print(f"Skipping row {index} due to invalid coordinates (NaN, inf, -inf) in sheet {sheet_name}")
                    problematic_records.append(row.to_dict())

            except (KeyError, TypeError, ValueError):
                print(f"Skipping row {index} due to missing or invalid coordinates in sheet {sheet_name}")
                problematic_records.append(row.to_dict())
                continue

        # Extract geometries and valid indices
        geometry = [geom for _, geom in geometry_with_indices]
        valid_indices = [index for index, _ in geometry_with_indices]

        # Filter the DataFrame to keep only rows with valid geometries
        df = df.loc[valid_indices]

    # Store problematic records for this sheet
    if problematic_records:
        problematic_records_dict[sheet_name] = pd.DataFrame(problematic_records)

    gdf = gpd.GeoDataFrame(df, geometry=geometry, crs="EPSG:4326")  # Set a proper CRS

    batas_wilayah = gpd.read_file('/content/drive/MyDrive/LALIN DC/Prop. Data/batas wilayah kota/Batas_Kota_Kabupaten_JABAR.shp')
    gdf = gpd.sjoin(gdf, batas_wilayah[['geometry', 'NAMOBJ']], how="left", predicate="intersects")

    qml_folder = "/content/drive/MyDrive/LALIN DC/QML file_copy"  # Path where .qml files are stored

    for name, group in gdf.groupby(['NAMOBJ', 'Nama Ruas Jalan', 'Jenis File']):
        kabupaten_kota, jalan_name, jenis_file = name

        # Ensure directory structure
        sanitized_kabupaten = "".join(c for c in kabupaten_kota if c.isalnum() or c in (' ', '_')).strip()
        sanitized_jalan = "".join(c for c in jalan_name if c.isalnum() or c in (' ', '_')).strip()
        sanitized_jenis = "".join(c for c in jenis_file if c.isalnum() or c in (' ', '_')).strip()

        jalan_folder = os.path.join(output_folder, sanitized_kabupaten, "Jalan Prioritas", sanitized_jenis)
        os.makedirs(jalan_folder, exist_ok=True)

        # Save shapefile
        shapefile_path = os.path.join(jalan_folder, f"{sanitized_jalan}_{sheet_name}.shp")
        with warnings.catch_warnings():
          warnings.filterwarnings('ignore', message='Normalized/laundered field name')
          warnings.filterwarnings('ignore', message='Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.')
          group.to_file(shapefile_path)

        # Apply QML Style
        qml_source_file = os.path.join(qml_folder, f"{sheet_name}.qml")  # Assuming QML file follows sheet name
        qml_target_file = shapefile_path.replace(".shp", ".qml")

        if os.path.exists(qml_source_file):
            shutil.copy(qml_source_file, qml_target_file)
            print(f"Applied QML style: {qml_target_file}")
        else:
            print(f"No QML file found for {sheet_name}")


# Save all problematic records into one Excel file with multiple sheets
if problematic_records_dict:
    with pd.ExcelWriter("/content/drive/MyDrive/LALIN DC/problematic_records.xlsx") as writer:
        for sheet, df in problematic_records_dict.items():
            df.to_excel(writer, sheet_name=sheet, index=False)

    print("Saved all problematic records to 'problematic_records.xlsx' with proper sheet names.")
# Out:
# Download 100%.
# Processing sheet: 1 RAMBU
# Skipping row 1957 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 2499 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 2751 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 2752 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 2961 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 3509 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 3510 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 3514 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 3515 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 3548 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 3549 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 3552 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 3553 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 3757 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 3758 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 3913 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 3919 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 3920 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 3924 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 5416 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 5686 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 5907 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 6052 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 6053 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 6055 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 6056 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 7622 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 7811 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 7812 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 8017 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 8208 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 8209 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 8210 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 8211 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 8283 due to missing or invalid coordinates in sheet 1 RAMBU
# Skipping row 10280 due to missing or invalid coordinates in sheet 1 RAMBU
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Bojongsoang  Sp Munjul_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung/Jalan Prioritas/Kebutuhan/Ruas Jalan Bojongsoang  Sp Munjul_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Cisewu Pangalengan_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung/Jalan Prioritas/Kebutuhan/Ruas Jalan Cisewu Pangalengan_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Kopo  Soreang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung/Jalan Prioritas/Kebutuhan/Ruas Jalan Kopo  Soreang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Nagreg  Bts Garut_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung/Jalan Prioritas/Kebutuhan/Ruas Jalan Nagreg  Bts Garut_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Pangalengan  Banjaran_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung/Jalan Prioritas/Kebutuhan/Ruas Jalan Pangalengan  Banjaran_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Purwakarta  Wanayasa_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung/Jalan Prioritas/Kebutuhan/Ruas Jalan Terusan Buah Batu Bts KotaKab Bandung  Bojongsoang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Terusan Buah Batu  Sp Kersen_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Eksisting/Ruas Jalan Bts Bandung  Lembang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Kebutuhan/Ruas Jalan Bts Bandung  Lembang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Eksisting/Ruas Jalan Bts Cimahi  Cisarua  Lembang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Kebutuhan/Ruas Jalan Bts Cimahi  Cisarua  Lembang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Eksisting/Ruas Jalan Grand Hotel Lembang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Kebutuhan/Ruas Jalan Grand Hotel Lembang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Eksisting/Ruas Jalan Lembang  Bts Subang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Kebutuhan/Ruas Jalan Lembang  Bts Subang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Eksisting/Ruas Jalan Lembang  Maribaya_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Kebutuhan/Ruas Jalan Lembang  Maribaya_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Eksisting/Ruas Jalan Padalarang  Cisarua_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Kebutuhan/Ruas Jalan Padalarang  Cisarua_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Eksisting/Ruas Jalan Pahlawan Kab Purwakarta_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Kebutuhan/Ruas Jalan Panorama Lembang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Eksisting/Ruas Jalan Purwakarta  Wanayasa_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Eksisting/Ruas Jalan Raya Lembang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Kebutuhan/Ruas Jalan Raya Lembang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Eksisting/Ruas Jalan Sadang Bts Purwakarta_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Eksisting/Ruas Jalan Sp Orion  Cihaliwung_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Kebutuhan/Ruas Jalan Sp Orion  Cihaliwung_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bekasi/Jalan Prioritas/Eksisting/Akses Dryport Cikarang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bekasi/Jalan Prioritas/Eksisting/Ruas Jalan KH R Mamun Nawawi_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bekasi/Jalan Prioritas/Kebutuhan/Ruas Jalan KH R Mamun Nawawi_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bekasi/Jalan Prioritas/Eksisting/Ruas Jalan Raya Lemah Abang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Bts Kota Bogor Kedung Halang  Sp 3 Kedung Halang Jl Raya Pemda_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Bts Tanggerang  Parung_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Bunar  Parung Panjang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Bunar  Parung Panjang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Cariu  JagatamuBaged BTS Kab BogorKarawang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Cariu  JagatamuBaged BTS Kab BogorKarawang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Cibarusah  Cibucil_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Cibarusah  Cibucil_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Cileungsi  Cibeet_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Cileungsi  Cibeet_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Cileungsi  Cibinong Citeureup_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Cileungsi  Cibinong Citeureup_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Harapan Jaya  Bts Kota Bogor_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Moch Toha Parung Panjang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Moch Toha Parung Panjang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Narogong  Cileungsi_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Narogong  Cileungsi_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Pondok Rajeg  Jl Harapan Jaya_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Ciamis/Jalan Prioritas/Eksisting/Ruas Jalan Warudoyong Bts Kab TasikmalayaCiamis  SP3 Winduraja Kawali_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Ciamis/Jalan Prioritas/Kebutuhan/Ruas Jalan Warudoyong Bts Kab TasikmalayaCiamis  SP3 Winduraja Kawali_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Cianjur/Jalan Prioritas/Kebutuhan/Ruas Jalan Cikadu  Sp Pancuh Tilu_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Cianjur/Jalan Prioritas/Eksisting/Ruas Jalan Selajambe  Cibogo  Cibeet_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Cianjur/Jalan Prioritas/Kebutuhan/Ruas Jalan Selajambe  Cibogo  Cibeet_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Cirebon/Jalan Prioritas/Eksisting/Ruas Jalan Budur  Susukan  Tegalgubug_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Cirebon/Jalan Prioritas/Eksisting/Ruas Jalan Mandirancan  Pakembangan_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Cirebon/Jalan Prioritas/Kebutuhan/Ruas Jalan Mandirancan  Pakembangan_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Cirebon/Jalan Prioritas/Kebutuhan/Ruas Jalan Susukan  Budur  Tegalgubug_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Kebutuhan/Ruas Jalan Bratayuda_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Kebutuhan/Ruas Jalan Brigjen Waskita Kusumah_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Bts Bandung  Garut_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Kebutuhan/Ruas Jalan Bts Bandung  Garut_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Cagak  Bts Subang  Sumedang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Cibadak  Cikidang  Pelabuhan Ratu_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Cikajang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Kebutuhan/Ruas Jalan Cikajang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Cikajang  Pameungpeuk_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Kebutuhan/Ruas Jalan Cikajang  Pameungpeuk_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Ciledug Kab Garut_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Kebutuhan/Ruas Jalan Ciledug Kab Garut_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Cimanuk I_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Kebutuhan/Ruas Jalan Cimanuk I_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Cimanuk II_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Kebutuhan/Ruas Jalan Cimanuk II_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Garut  Bts GarutTasikmalaya_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Kebutuhan/Ruas Jalan Garut  Bts GarutTasikmalaya_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Garut  Cikajang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Kebutuhan/Ruas Jalan Garut  Cikajang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Jatibarang  Bts MajalengkaIndramayu_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Kadipaten  Bts MajalengkaIndramayu_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Kebon Kawung Sp Cicendo  Sp Pasirkaliki_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Kopo  Soreang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Kebutuhan/Ruas Jalan Lembang  Bts Subang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Malangbong_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Kebutuhan/Ruas Jalan Malangbong_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Merdeka Kab Garut_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Kebutuhan/Ruas Jalan Merdeka Kab Garut_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Otista Kab Garut_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Pameungpeuk_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Kebutuhan/Ruas Jalan Pameungpeuk_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Pangalengan  Banjaran_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Sp Krisik Wado  Bts Sumedang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Sudirman Kab Garut_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Kebutuhan/Ruas Jalan Sudirman Kab Garut_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Suherman_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Kebutuhan/Ruas Jalan Suherman_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Kebutuhan/Ruas Jalan Tanjung Pura  Batujaya_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Indramayu/Jalan Prioritas/Kebutuhan/Ruas Jalan Cikamurang  Bantarwaru Bts Subang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Indramayu/Jalan Prioritas/Eksisting/Ruas Jalan Jangga  Cikamurang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Indramayu/Jalan Prioritas/Kebutuhan/Ruas Jalan Jangga  Cikamurang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Indramayu/Jalan Prioritas/Eksisting/Ruas Jalan Jatibarang  Bts MajalengkaIndramayu_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Indramayu/Jalan Prioritas/Kebutuhan/Ruas Jalan Jatibarang  Bts MajalengkaIndramayu_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Indramayu/Jalan Prioritas/Eksisting/Ruas Jalan Karangampel  Jatibarang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Indramayu/Jalan Prioritas/Kebutuhan/Ruas Jalan Karangampel  Jatibarang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Indramayu/Jalan Prioritas/Eksisting/Ruas Jalan Mundu  Gopala_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Indramayu/Jalan Prioritas/Kebutuhan/Ruas Jalan Mundu  Gopala_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Indramayu/Jalan Prioritas/Eksisting/Ruas Jalan Patrol  Haurgeulis_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Indramayu/Jalan Prioritas/Kebutuhan/Ruas Jalan Patrol  Haurgeulis_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Karawang/Jalan Prioritas/Kebutuhan/Ruas Jalan Kosambi  Curug Bts KarawangPurwakarta_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Karawang/Jalan Prioritas/Eksisting/Ruas Jalan Loji Tegalnyampah  Balewer  Puncak Darma_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Karawang/Jalan Prioritas/Eksisting/Ruas Jalan Palumbonsari  Johar  Tegalloa Loji_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Karawang/Jalan Prioritas/Eksisting/Ruas Jalan Proklamasi Kab Karawang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Karawang/Jalan Prioritas/Kebutuhan/Ruas Jalan Proklamasi Kab Karawang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Karawang/Jalan Prioritas/Eksisting/Ruas Jalan Tanjung Pura  Batujaya_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Karawang/Jalan Prioritas/Kebutuhan/Ruas Jalan Tanjung Pura  Batujaya_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Karawang/Jalan Prioritas/Eksisting/Ruas Jalan Tegalloa  BagedJagatamu  Bts Kab KarawangKab Bogor_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Karawang/Jalan Prioritas/Kebutuhan/Ruas Jalan Tegalloa  BagedJagatamu  Bts Kab KarawangKab Bogor_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Kuningan/Jalan Prioritas/Eksisting/Ruas Jalan Kuningan  Ciawigebang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Kuningan/Jalan Prioritas/Kebutuhan/Ruas Jalan Kuningan  Ciawigebang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Kuningan/Jalan Prioritas/Eksisting/Ruas Jalan Luragung  Cibingbin_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Kuningan/Jalan Prioritas/Kebutuhan/Ruas Jalan Luragung  Cibingbin_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Kuningan/Jalan Prioritas/Eksisting/Ruas Jalan Mandirancan  Pakembangan_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Kuningan/Jalan Prioritas/Kebutuhan/Ruas Jalan Mandirancan  Pakembangan_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Kuningan/Jalan Prioritas/Eksisting/Ruas Jalan Pakembangan  Bojong_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Kuningan/Jalan Prioritas/Kebutuhan/Ruas Jalan Pakembangan  Bojong_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Kuningan/Jalan Prioritas/Eksisting/Ruas Jalan RE Martadinata Kuningan_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Kuningan/Jalan Prioritas/Kebutuhan/Ruas Jalan RE Martadinata Kuningan_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Kuningan/Jalan Prioritas/Eksisting/Ruas Jalan Siliwangi Kuningan_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Kuningan/Jalan Prioritas/Kebutuhan/Ruas Jalan Siliwangi Kuningan_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Majalengka/Jalan Prioritas/Eksisting/Ruas Jalan Akses Bandara Kertajati_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Majalengka/Jalan Prioritas/Kebutuhan/Ruas Jalan Akses Bandara Kertajati_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Majalengka/Jalan Prioritas/Eksisting/Ruas Jalan Jatibarang  Bts MajalengkaIndramayu_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Majalengka/Jalan Prioritas/Kebutuhan/Ruas Jalan Jatibarang  Bts MajalengkaIndramayu_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Majalengka/Jalan Prioritas/Eksisting/Ruas Jalan Kadipaten  Bts MajalengkaIndramayu_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Majalengka/Jalan Prioritas/Kebutuhan/Ruas Jalan Kadipaten  Bts MajalengkaIndramayu_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Pangandaran/Jalan Prioritas/Eksisting/Ruas Jalan Bandara Nusawiru_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Pangandaran/Jalan Prioritas/Kebutuhan/Ruas Jalan Bandara Nusawiru_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Purwakarta/Jalan Prioritas/Eksisting/Ruas Jalan Bts Purwakarta  Cagak_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Purwakarta/Jalan Prioritas/Kebutuhan/Ruas Jalan Bts Purwakarta  Cagak_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Purwakarta/Jalan Prioritas/Kebutuhan/Ruas Jalan Kosambi  Curug Bts KarawangPurwakarta_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Purwakarta/Jalan Prioritas/Eksisting/Ruas Jalan Pahlawan Kab Purwakarta_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Purwakarta/Jalan Prioritas/Kebutuhan/Ruas Jalan Pahlawan Kab Purwakarta_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Purwakarta/Jalan Prioritas/Eksisting/Ruas Jalan Purwakarta  Curug Bts KarawangPurwakarta_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Purwakarta/Jalan Prioritas/Kebutuhan/Ruas Jalan Purwakarta  Curug Bts KarawangPurwakarta_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Purwakarta/Jalan Prioritas/Eksisting/Ruas Jalan Purwakarta  Wanayasa_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Purwakarta/Jalan Prioritas/Kebutuhan/Ruas Jalan Purwakarta  Wanayasa_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Purwakarta/Jalan Prioritas/Eksisting/Ruas Jalan Sadang Bts Purwakarta_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Purwakarta/Jalan Prioritas/Kebutuhan/Ruas Jalan Sadang Bts Purwakarta_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Purwakarta/Jalan Prioritas/Eksisting/Ruas Jalan Sp Purwakarta  Jatiluhur_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Purwakarta/Jalan Prioritas/Kebutuhan/Ruas Jalan Sp Purwakarta  Jatiluhur_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Eksisting/Ruas Jalan Ahmad Yani Kab Subang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Kebutuhan/Ruas Jalan Ahmad Yani Kab Subang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Eksisting/Ruas Jalan Bts Purwakarta  Cagak_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Kebutuhan/Ruas Jalan Bts Purwakarta  Cagak_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Eksisting/Ruas Jalan Cagak  Bts Subang  Sumedang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Kebutuhan/Ruas Jalan Cagak  Bts Subang  Sumedang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Eksisting/Ruas Jalan Lembang  Bts Subang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Eksisting/Ruas Jalan Masjid Agung_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Kebutuhan/Ruas Jalan Masjid Agung_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Eksisting/Ruas Jalan Otto Iskandardinata Kab Subang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Kebutuhan/Ruas Jalan Otto Iskandardinata Kab Subang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Kebutuhan/Ruas Jalan Pamanukan  Pegaden_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Eksisting/Ruas Jalan Pegaden  Pemanukan_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Eksisting/Ruas Jalan Purwakarta  Curug Bts KarawangPurwakarta_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Eksisting/Ruas Jalan Purwakarta  Wanayasa_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Eksisting/Ruas Jalan S Parman Kab Subang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Eksisting/Ruas Jalan Sadang Bts Purwakarta_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Eksisting/Ruas Jalan Sp Purwakarta  Jatiluhur_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Eksisting/Ruas Jalan Subang  Bts Bandung_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Kebutuhan/Ruas Jalan Subang  Bts Bandung_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Eksisting/Ruas Jalan Subang  Bts Purwakarta_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Kebutuhan/Ruas Jalan Subang  Bts Purwakarta_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Eksisting/Ruas Jalan Bhayangkara Pelabuhan Ratu Kab Sukabumi_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Eksisting/Ruas Jalan Cibadak  Cikidang  Pelabuhan Ratu_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Kebutuhan/Ruas Jalan Cibadak  Cikidang  Pelabuhan Ratu_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Eksisting/Ruas Jalan Cikembar  Cikembang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Kebutuhan/Ruas Jalan Cikembar  Cikembang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Kebutuhan/Ruas Jalan Cileungsi  Cibeet_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Kebutuhan/Ruas Jalan Edi Sukardi Kota Sukabumi_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Eksisting/Ruas Jalan Gudang Sagaranten_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Kebutuhan/Ruas Jalan Gudang Sagaranten_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Eksisting/Ruas Jalan Karanghawu  Cikotok Bts Banten_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Kebutuhan/Ruas Jalan Karanghawu  Cikotok Bts Banten_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Eksisting/Ruas Jalan Loji Tegalnyampah  Balewer  Puncak Darma_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Kebutuhan/Ruas Jalan Loji Tegalnyampah  Balewer  Puncak Darma_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Eksisting/Ruas Jalan Palangpang  Puncak Dharma_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Eksisting/Ruas Jalan Sp Surade  Ujunggenteng_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Kebutuhan/Ruas Jalan Sp Surade  Ujunggenteng_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Eksisting/Ruas Jalan Sukabumi  Cikembar_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Kebutuhan/Ruas Jalan Sukabumi  Cikembar_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sumedang/Jalan Prioritas/Eksisting/Ruas Jalan Cagak  Bts Subang  Sumedang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sumedang/Jalan Prioritas/Eksisting/Ruas Jalan Cijelag  Bts Sumedang  Indramayu_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sumedang/Jalan Prioritas/Kebutuhan/Ruas Jalan Cijelag  Bts Sumedang  Indramayu_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sumedang/Jalan Prioritas/Eksisting/Ruas Jalan Lembang  Maribaya_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sumedang/Jalan Prioritas/Eksisting/Ruas Jalan Purwakarta  Wanayasa_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sumedang/Jalan Prioritas/Eksisting/Ruas Jalan Situraja  Darmaraja_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sumedang/Jalan Prioritas/Kebutuhan/Ruas Jalan Situraja  Darmaraja_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sumedang/Jalan Prioritas/Eksisting/Ruas Jalan Sp Krisik Wado  Bts Sumedang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sumedang/Jalan Prioritas/Kebutuhan/Ruas Jalan Sp Krisik Wado  Bts Sumedang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sumedang/Jalan Prioritas/Eksisting/Ruas Jalan Sumedang  Cikaramas_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sumedang/Jalan Prioritas/Kebutuhan/Ruas Jalan Sumedang  Cikaramas_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Tasikmalaya/Jalan Prioritas/Eksisting/Ruas Jalan Bts GarutTasikmalaya  Singaparna_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Bts GarutTasikmalaya  Singaparna_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Tasikmalaya/Jalan Prioritas/Eksisting/Ruas Jalan Garuda Tasikmalaya_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Tasikmalaya/Jalan Prioritas/Eksisting/Ruas Jalan Garut  Bts GarutTasikmalaya_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Tasikmalaya/Jalan Prioritas/Eksisting/Ruas Jalan Gubernur Sewaka_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Singaparna  Bts Kota Kab Tasikmalaya Cikunir_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Tasikmalaya/Jalan Prioritas/Eksisting/Ruas Jalan Singaparna  Tasikmalaya_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Tasikmalaya/Jalan Prioritas/Eksisting/Ruas Jalan Tasikmalaya  Karangnunggal_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Tasikmalaya  Karangnunggal_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Bts Bandung  Lembang_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Cicendo Sp Pajajaran  Sp Kebon Kawung_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Kebutuhan/Ruas Jalan Cicendo Sp Pajajaran  Sp Kebon Kawung_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Kebon Kawung Sp Cicendo  Sp Pasirkaliki_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Kebutuhan/Ruas Jalan Kebon Kawung Sp Cicendo  Sp Pasirkaliki_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Pajajaran Akses Bandara Husein Sastranegara_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Kebutuhan/Ruas Jalan Pajajaran Akses Bandara Husein Sastranegara_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Pajajaran Sp Pasirkaliki  Sp Cicendo_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Kebutuhan/Ruas Jalan Pajajaran Sp Pasirkaliki  Sp Cicendo_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Pasirkaliki Sp Kebonkawung  Sp Pajajaran_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Kebutuhan/Ruas Jalan Pasirkaliki Sp Kebonkawung  Sp Pajajaran_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Pasirkaliki Sp Pasteur  Sp Sukajadi_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Kebutuhan/Ruas Jalan Pasirkaliki Sp Pasteur  Sp Sukajadi_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Setiabudi Bandung_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Kebutuhan/Ruas Jalan Setiabudi Bandung_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Sukajadi Bandung_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Kebutuhan/Ruas Jalan Sukajadi Bandung_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Sukawangi Bandung_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bekasi/Jalan Prioritas/Eksisting/Ruas Jalan Cileungsi  Cibeet_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bekasi/Jalan Prioritas/Eksisting/Ruas Jalan Juanda Kota Bekasi_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bekasi/Jalan Prioritas/Kebutuhan/Ruas Jalan Juanda Kota Bekasi_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bekasi/Jalan Prioritas/Eksisting/Ruas Jalan Kartini Kota Bekasi_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bekasi/Jalan Prioritas/Eksisting/Ruas Jalan Perjuangan Kota Bekasi_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bekasi/Jalan Prioritas/Kebutuhan/Ruas Jalan Perjuangan Kota Bekasi_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Batu Tulis Kota Bogor_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Batu Tulis Kota Bogor_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Bts Kota Bogor Kedung Halang  Sp 3 Kedung Halang Jl Raya Pemda_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Bts Kota Bogor Kedung Halang  Sp 3 Kedung Halang Jl Raya Pemda_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Empang  Jalan R Saleh Sarief Bustaman Kota Bogor_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Empang  Jalan R Saleh Sarief Bustaman Kota Bogor_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Ir H Juanda Kota Bogor_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Ir H Juanda Kota Bogor_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Jend Sudirman Kota Bogor_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Jend Sudirman Kota Bogor_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Kebon Pedes Kota Bogor_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Kebon Pedes Kota Bogor_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Lawang Gintung Kota Bogor_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Lawang Gintung Kota Bogor_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Pahlawan Kota Bogor_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Pahlawan Kota Bogor_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Siliwangi Kota Bogor_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Siliwangi Kota Bogor_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Cimahi/Jalan Prioritas/Eksisting/Ruas Jalan Purwakarta  Wanayasa_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Sukabumi/Jalan Prioritas/Kebutuhan/Ruas Jalan Edi Sukardi Kota Sukabumi_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Eksisting/Ruas Jalan Brigjen Waskita Kusumah_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Brigjen Waskita Kusumah_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Eksisting/Ruas Jalan Cisumur  Garuda Letjen Mashudi_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Cisumur  Garuda Letjen Mashudi_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Eksisting/Ruas Jalan Garuda Tasikmalaya_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Garuda Tasikmalaya_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Eksisting/Ruas Jalan Gubernur Sewaka_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Gubernur Sewaka_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Eksisting/Ruas Jalan Ir H Djuanda Tasikmalaya_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Ir H Djuanda Tasikmalaya_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Eksisting/Ruas Jalan Letnan Harun_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Letnan Harun_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Eksisting/Ruas Jalan Perintis Kemerdekaan  Sukaraja Bts KotaKab Tasikmalaya_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Perintis Kemerdekaan  Sukaraja Bts KotaKab Tasikmalaya_1 RAMBU.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Eksisting/Ruas Jalan Singaparna  Tasikmalaya_1 RAMBU.qml
# Processing sheet: 2 PJU
# Skipping row 818 due to missing or invalid coordinates in sheet 2 PJU
# Skipping row 3187 due to missing or invalid coordinates in sheet 2 PJU
# Skipping row 3211 due to missing or invalid coordinates in sheet 2 PJU
# Skipping row 3214 due to missing or invalid coordinates in sheet 2 PJU
# Skipping row 4008 due to missing or invalid coordinates in sheet 2 PJU
# Skipping row 4590 due to missing or invalid coordinates in sheet 2 PJU
# Skipping row 5785 due to missing or invalid coordinates in sheet 2 PJU
# Skipping row 5787 due to missing or invalid coordinates in sheet 2 PJU
# ...
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Eksisting/Ruas Jalan Loji Tegalnyampah  Balewer  Puncak Darma_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Eksisting/Ruas Jalan Sp Surade  Ujunggenteng_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Kebutuhan/Ruas Jalan Sp Surade  Ujunggenteng_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Eksisting/Ruas Jalan Sukabumi  Cikembar_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Kebutuhan/Ruas Jalan Sukabumi  Cikembar_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sumedang/Jalan Prioritas/Eksisting/Ruas Jalan Cijelag  Bts Sumedang  Indramayu_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sumedang/Jalan Prioritas/Kebutuhan/Ruas Jalan Cileungsi  Cibeet_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sumedang/Jalan Prioritas/Eksisting/Ruas Jalan Situraja  Darmaraja_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sumedang/Jalan Prioritas/Eksisting/Ruas Jalan Sp Krisik Wado  Bts Sumedang_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Tasikmalaya/Jalan Prioritas/Eksisting/Ruas Jalan Bts GarutTasikmalaya  Singaparna_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Bts GarutTasikmalaya  Singaparna_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Singaparna  Bts Kota Kab Tasikmalaya Cikunir_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Tasikmalaya/Jalan Prioritas/Eksisting/Ruas Jalan Singaparna  Tasikmalaya_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Tasikmalaya/Jalan Prioritas/Eksisting/Ruas Jalan Tasikmalaya  Karangnunggal_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Tasikmalaya  Karangnunggal_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Cicendo Sp Pajajaran  Sp Kebon Kawung_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Kebon Kawung Sp Cicendo  Sp Pasirkaliki_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Kebutuhan/Ruas Jalan Kebon Kawung Sp Cicendo  Sp Pasirkaliki_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Pajajaran Akses Bandara Husein Sastranegara_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Kebutuhan/Ruas Jalan Pajajaran Akses Bandara Husein Sastranegara_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Pajajaran Sp Pasirkaliki  Sp Cicendo_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Pasirkaliki Sp Kebonkawung  Sp Pajajaran_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Pasirkaliki Sp Pasteur  Sp Sukajadi_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Setiabudi Bandung_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Kebutuhan/Ruas Jalan Setiabudi Bandung_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Sukajadi Bandung_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bandung/Jalan Prioritas/Kebutuhan/Ruas Jalan Sukajadi Bandung_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bekasi/Jalan Prioritas/Eksisting/Ruas Jalan Juanda Kota Bekasi_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bekasi/Jalan Prioritas/Eksisting/Ruas Jalan Kartini Kota Bekasi_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Batu Tulis Kota Bogor_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Bts Kota Bogor Kedung Halang  Sp 3 Kedung Halang Jl Raya Pemda_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Empang  Jalan R Saleh Sarief Bustaman Kota Bogor_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Empang  Jalan R Saleh Sarief Bustaman Kota Bogor_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Ir H Juanda Kota Bogor_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Ir H Juanda Kota Bogor_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Jend Sudirman Kota Bogor_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Kebon Pedes Kota Bogor_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Kebon Pedes Kota Bogor_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Lawang Gintung Kota Bogor_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Pahlawan Kota Bogor_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Siliwangi Kota Bogor_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Siliwangi Kota Bogor_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Sukabumi/Jalan Prioritas/Kebutuhan/Ruas Jalan Edi Sukardi Kota Sukabumi_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Brigjen Waskita Kusumah_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Cisumur  Garuda Letjen Mashudi_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Garuda Tasikmalaya_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Gubernur Sewaka_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Eksisting/Ruas Jalan Ir H Djuanda Tasikmalaya_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Ir H Djuanda Tasikmalaya_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Letnan Harun_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Eksisting/Ruas Jalan Perintis Kemerdekaan  Sukaraja Bts KotaKab Tasikmalaya_9 FAS PENYEBRANGAN.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kota Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Perintis Kemerdekaan  Sukaraja Bts KotaKab Tasikmalaya_9 FAS PENYEBRANGAN.qml
# Processing sheet: 13 CERMIN TIKUNG
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung/Jalan Prioritas/Eksisting/Ruas Jalan Pangalengan  Banjaran_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Eksisting/Ruas Jalan Bts Bandung  Lembang_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Eksisting/Ruas Jalan Bts Cimahi  Cisarua  Lembang_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Eksisting/Ruas Jalan Padalarang  Cisarua_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Eksisting/Ruas Jalan Raya Lembang_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Eksisting/Ruas Jalan Sadang Bts Purwakarta_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bandung Barat/Jalan Prioritas/Eksisting/Ruas Jalan Sp Orion  Cihaliwung_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Eksisting/Ruas Jalan Cileungsi  Cibinong Citeureup_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Bogor/Jalan Prioritas/Kebutuhan/Ruas Jalan Cileungsi  Cibinong Citeureup_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Ciamis/Jalan Prioritas/Kebutuhan/Ruas Jalan Warudoyong Bts Kab TasikmalayaCiamis  SP3 Winduraja Kawali_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Kebutuhan/Ruas Jalan Cikajang  Pameungpeuk_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Garut/Jalan Prioritas/Eksisting/Ruas Jalan Garuda Tasikmalaya_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Karawang/Jalan Prioritas/Eksisting/Ruas Jalan Purwakarta  Wanayasa_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Kuningan/Jalan Prioritas/Eksisting/Ruas Jalan Mandirancan  Pakembangan_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Eksisting/Ruas Jalan Bts Purwakarta  Cagak_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Kebutuhan/Ruas Jalan Cagak  Bts Subang  Sumedang_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Eksisting/Ruas Jalan Sadang Bts Purwakarta_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Subang/Jalan Prioritas/Kebutuhan/Ruas Jalan Subang  Bts Purwakarta_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Kebutuhan/Ruas Jalan Karanghawu  Cikotok Bts Banten_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Eksisting/Ruas Jalan Loji Tegalnyampah  Balewer  Puncak Darma_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sukabumi/Jalan Prioritas/Kebutuhan/Ruas Jalan Sp Surade  Ujunggenteng_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Sumedang/Jalan Prioritas/Eksisting/Ruas Jalan Sumedang  Cikaramas_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Bts GarutTasikmalaya  Singaparna_13 CERMIN TIKUNG.qml
# Applied QML style: /content/drive/MyDrive/LALIN DC/Final Upload Shp v2/Kabupaten Tasikmalaya/Jalan Prioritas/Kebutuhan/Ruas Jalan Tasikmalaya  Karangnunggal_13 CERMIN TIKUNG.qml
# Processing sheet: 10 RAMBU PORTABLE
# Skipping row 0 due to missing or invalid coordinates in sheet 10 RAMBU PORTABLE
# Skipping row 1 due to missing or invalid coordinates in sheet 10 RAMBU PORTABLE
# Skipping row 2 due to missing or invalid coordinates in sheet 10 RAMBU PORTABLE
# Skipping row 3 due to missing or invalid coordinates in sheet 10 RAMBU PORTABLE
# Skipping row 4 due to missing or invalid coordinates in sheet 10 RAMBU PORTABLE
# Skipping row 5 due to missing or invalid coordinates in sheet 10 RAMBU PORTABLE
# Skipping row 6 due to missing or invalid coordinates in sheet 10 RAMBU PORTABLE
# Skipping row 7 due to missing or invalid coordinates in sheet 10 RAMBU PORTABLE
# Skipping row 8 due to missing or invalid coordinates in sheet 10 RAMBU PORTABLE
# Skipping row 9 due to missing or invalid coordinates in sheet 10 RAMBU PORTABLE
# Skipping row 10 due to missing or invalid coordinates in sheet 10 RAMBU PORTABLE
# Skipping row 11 due to missing or invalid coordinates in sheet 10 RAMBU PORTABLE
# Skipping row 12 due to missing or invalid coordinates in sheet 10 RAMBU PORTABLE
# Processing sheet: 11 TRAFFIC CONE
# Skipping row 0 due to missing or invalid coordinates in sheet 11 TRAFFIC CONE
# Skipping row 1 due to missing or invalid coordinates in sheet 11 TRAFFIC CONE
# Skipping row 2 due to missing or invalid coordinates in sheet 11 TRAFFIC CONE
# Skipping row 3 due to missing or invalid coordinates in sheet 11 TRAFFIC CONE
# Skipping row 4 due to missing or invalid coordinates in sheet 11 TRAFFIC CONE
# Processing sheet: 12 WATER BARRIER
# Skipping row 0 due to missing or invalid coordinates in sheet 12 WATER BARRIER
# Skipping row 1 due to missing or invalid coordinates in sheet 12 WATER BARRIER
# Skipping row 2 due to missing or invalid coordinates in sheet 12 WATER BARRIER
# Skipping row 3 due to missing or invalid coordinates in sheet 12 WATER BARRIER
# Skipping row 4 due to missing or invalid coordinates in sheet 12 WATER BARRIER
# Skipping row 5 due to missing or invalid coordinates in sheet 12 WATER BARRIER
# Skipping row 6 due to missing or invalid coordinates in sheet 12 WATER BARRIER
# Skipping row 7 due to missing or invalid coordinates in sheet 12 WATER BARRIER
# Skipping row 8 due to missing or invalid coordinates in sheet 12 WATER BARRIER
# Skipping row 9 due to missing or invalid coordinates in sheet 12 WATER BARRIER
# Skipping row 10 due to missing or invalid coordinates in sheet 12 WATER BARRIER
# Saved all problematic records to 'problematic_records.xlsx' with proper sheet names.

# %%
from google.colab import drive
import os
import geopandas as gpd
import pandas as pd
import shutil

# Mount Google Drive (if using Colab)
drive.mount('/content/drive')

# Define input shapefile path
shapefile_path = '/content/drive/MyDrive/LALIN DC/Prop. Data/shp ruas jalan provinsi jabar/SHP PROVINSI FINAL 14032023/SHP JALAN PROVINSI FINAL 14032023 FINAL.shp'

# Define output directory
output_folder = '/content/drive/MyDrive/LALIN DC/Ruas Jalan Splitted'
os.makedirs(output_folder, exist_ok=True)

# Load the shapefile
gdf = gpd.read_file(shapefile_path)

# Check if required columns exist
if 'nama jalan' not in gdf.columns or 'kabupaten/' not in gdf.columns:
    raise ValueError("The shapefile is missing required columns: 'nama jalan' or 'kabupaten/'")

# List to store data for Excel
excel_data = []

# Group by 'kabupaten/' and export each row separately
for kabupaten, group in gdf.groupby('kabupaten/'):
    kabupaten_folder = os.path.join(output_folder, kabupaten)
    os.makedirs(kabupaten_folder, exist_ok=True)

    for index, row in group.iterrows():
        jalan_name = row['nama jalan']

        # Sanitize file name (replace non-alphanumeric characters with underscores)
        sanitized_jalan = "".join(c if c.isalnum() or c in (' ', '_') else "_" for c in jalan_name).strip()

        # Define shapefile path
        shapefile_output_path = os.path.join(kabupaten_folder, f"{sanitized_jalan}.shp")

        # Convert row to a GeoDataFrame correctly
        gdf_row = gpd.GeoDataFrame.from_dict({col: [row[col]] for col in gdf.columns})
        gdf_row.set_geometry([row.geometry], inplace=True)  # Ensure geometry is correctly set
        gdf_row.set_crs(gdf.crs, inplace=True)  # Maintain CRS

        # Save as a separate shapefile
        gdf_row.to_file(shapefile_output_path)

        # Store data for Excel
        excel_data.append([jalan_name, kabupaten])

# Convert data to a sorted Pandas DataFrame
df_excel = pd.DataFrame(excel_data, columns=['Nama Jalan', 'Kabupaten']).sort_values('Nama Jalan')

# Save to Excel
excel_output_path = os.path.join(output_folder, 'jalan_kabupaten.xlsx')
df_excel.to_excel(excel_output_path, index=False)

print("Export completed successfully!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Export completed successfully!
